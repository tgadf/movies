# %% [markdown]
# # Filmsite Functions

# %%
## Basic stuff
# %load_ext autoreload
# %autoreload
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))

## Python Version
import sys
print("Python: {0}".format(sys.version))

# %load_ext autoreload
# %autoreload

from films101 import films101

from timeUtils import clock
import datetime as dt
start = dt.datetime.now()
print("Notebook Last Run Initiated: "+str(start))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>
# Python: 3.6.6 |Anaconda custom (64-bit)| (default, Jun 28 2018, 11:07:29)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Notebook Last Run Initiated: 2019-02-28 18:00:30.934590

# %% [markdown]
# # Get/Parse/Merge/Process Films101 Data

# %%
f101 = films101()
f101.getFilms101YearlyData(startYear=1900, endYear=2018, debug=True)
_, _ = clock("Last Run")
# Out:
# Found 8 movies in 1900
# Found 11 movies in 1901
# Found 5 movies in 1902
# Found 8 movies in 1903
# Found 9 movies in 1904
# Found 7 movies in 1905
# Found 8 movies in 1906
# Found 10 movies in 1907
# Found 7 movies in 1908
# Found 13 movies in 1909
# Found 26 movies in 1910
# Found 19 movies in 1911
# Found 28 movies in 1912
# Found 23 movies in 1913
# Found 34 movies in 1914
# Found 25 movies in 1915
# Found 43 movies in 1916
# Found 34 movies in 1917
# Found 29 movies in 1918
# Found 32 movies in 1919
# Found 42 movies in 1920
# Found 35 movies in 1921
# Found 49 movies in 1922
# Found 36 movies in 1923
# Found 39 movies in 1924
# Found 53 movies in 1925
# Found 63 movies in 1926
# Found 60 movies in 1927
# Found 73 movies in 1928
# Found 92 movies in 1929
# Found 63 movies in 1930
# Found 79 movies in 1931
# Found 82 movies in 1932
# Found 105 movies in 1933
# Found 81 movies in 1934
# Found 87 movies in 1935
# Found 91 movies in 1936
# Found 80 movies in 1937
# Found 82 movies in 1938
# Found 86 movies in 1939
# Found 83 movies in 1940
# Found 77 movies in 1941
# Found 72 movies in 1942
# Found 85 movies in 1943
# Found 75 movies in 1944
# Found 74 movies in 1945
# Found 71 movies in 1946
# Found 76 movies in 1947
# Found 90 movies in 1948
# Found 87 movies in 1949
# Found 89 movies in 1950
# Found 83 movies in 1951
# Found 91 movies in 1952
# Found 104 movies in 1953
# Found 93 movies in 1954
# Found 108 movies in 1955
# Found 99 movies in 1956
# Found 115 movies in 1957
# Found 103 movies in 1958
# Found 98 movies in 1959
# Found 100 movies in 1960
# Found 86 movies in 1961
# Found 105 movies in 1962
# Found 96 movies in 1963
# Found 104 movies in 1964
# Found 97 movies in 1965
# Found 106 movies in 1966
# Found 107 movies in 1967
# Found 101 movies in 1968
# Found 90 movies in 1969
# Found 117 movies in 1970
# Found 108 movies in 1971
# Found 100 movies in 1972
# Found 93 movies in 1973
# Found 85 movies in 1974
# Found 88 movies in 1975
# Found 80 movies in 1976
# Found 85 movies in 1977
# Found 88 movies in 1978
# Found 94 movies in 1979
# Found 87 movies in 1980
# Found 89 movies in 1981
# Found 102 movies in 1982
# Found 106 movies in 1983
# Found 105 movies in 1984
# Found 101 movies in 1985
# Found 100 movies in 1986
# Found 112 movies in 1987
# Found 106 movies in 1988
# Found 99 movies in 1989
# Found 100 movies in 1990
# Found 115 movies in 1991
# Found 108 movies in 1992
# Found 111 movies in 1993
# Found 127 movies in 1994
# Found 164 movies in 1995
# Found 154 movies in 1996
# Found 148 movies in 1997
# Found 144 movies in 1998
# Found 145 movies in 1999
# Found 146 movies in 2000
# Found 150 movies in 2001
# Found 175 movies in 2002
# Found 154 movies in 2003
# Found 183 movies in 2004
# Found 194 movies in 2005
# Found 201 movies in 2006
# Found 180 movies in 2007
# Found 189 movies in 2008
# Found 204 movies in 2009
# Found 196 movies in 2010
# Found 202 movies in 2011
# Found 197 movies in 2012
# Found 139 movies in 2013
# Found 156 movies in 2014
# Found 150 movies in 2015
# Found 164 movies in 2016
# Found 146 movies in 2017
# Found 42 movies in 2018
# Saving 119 Years of films101 Data to /Users/tgadfort/Documents/code/movies/films101/results/films101.json
# Current Time is Thu Feb 28, 2019 17:23:30 for Last Run

# %%
f101.parseFilms101Data(debug=False)
_, _ = clock("Last Run")
# Out:
# Found 1 movies in 1902
# Found 1 movies in 1903
# Found 1 movies in 1914
# Found 2 movies in 1915
# Found 2 movies in 1916
# Found 1 movies in 1919
# Found 1 movies in 1920
# Found 5 movies in 1921
# Found 1 movies in 1922
# Found 5 movies in 1923
# Found 6 movies in 1924
# Found 7 movies in 1925
# Found 2 movies in 1926
# Found 8 movies in 1927
# Found 13 movies in 1928
# Found 9 movies in 1929
# Found 9 movies in 1930
# Found 13 movies in 1931
# Found 20 movies in 1932
# Found 16 movies in 1933
# Found 18 movies in 1934
# Found 19 movies in 1935
# Found 22 movies in 1936
# Found 23 movies in 1937
# Found 15 movies in 1938
# Found 23 movies in 1939
# Found 27 movies in 1940
# Found 17 movies in 1941
# Found 18 movies in 1942
# Found 16 movies in 1943
# Found 15 movies in 1944
# Found 17 movies in 1945
# Found 15 movies in 1946
# Found 17 movies in 1947
# Found 19 movies in 1948
# Found 14 movies in 1949
# Found 15 movies in 1950
# Found 14 movies in 1951
# Found 8 movies in 1952
# Found 16 movies in 1953
# Found 17 movies in 1954
# Found 21 movies in 1955
# Found 19 movies in 1956
# Found 19 movies in 1957
# Found 14 movies in 1958
# Found 20 movies in 1959
# Found 18 movies in 1960
# Found 17 movies in 1961
# Found 19 movies in 1962
# Found 15 movies in 1963
# Found 16 movies in 1964
# Found 12 movies in 1965
# Found 12 movies in 1966
# Found 14 movies in 1967
# Found 21 movies in 1968
# Found 18 movies in 1969
# Found 11 movies in 1970
# Found 19 movies in 1971
# Found 11 movies in 1972
# Found 20 movies in 1973
# Found 13 movies in 1974
# Found 15 movies in 1975
# Found 12 movies in 1976
# Found 13 movies in 1977
# Found 15 movies in 1978
# Found 20 movies in 1979
# Found 15 movies in 1980
# Found 24 movies in 1981
# Found 19 movies in 1982
# Found 15 movies in 1983
# Found 19 movies in 1984
# Found 22 movies in 1985
# Found 22 movies in 1986
# Found 27 movies in 1987
# Found 23 movies in 1988
# Found 19 movies in 1989
# Found 21 movies in 1990
# Found 15 movies in 1991
# Found 23 movies in 1992
# Found 21 movies in 1993
# Found 28 movies in 1994
# Found 22 movies in 1995
# Found 15 movies in 1996
# Found 17 movies in 1997
# Found 18 movies in 1998
# Found 17 movies in 1999
# Found 20 movies in 2000
# Found 19 movies in 2001
# Found 24 movies in 2002
# Found 23 movies in 2003
# Found 26 movies in 2004
# Found 24 movies in 2005
# Found 27 movies in 2006
# Found 20 movies in 2007
# Found 8 movies in 2008
# Found 5 movies in 2009
# Found 3 movies in 2010
# Found 5 movies in 2011
# Found 21 movies in 2012
# Found 30 movies in 2013
# Found 25 movies in 2014
# Found 31 movies in 2015
# Found 34 movies in 2016
# Found 18 movies in 2017
# Found 16 movies in 2018
# Saving 105 Years of Filmsite Data to /Users/tgadfort/Documents/code/movies/filmsite/results/filmsite.json
# Current Time is Thu Feb 14, 2019 19:31:08 for Last Run
